# %%
import pandas as pd

# %%
df = pd.read_csv("E:\datasets\listings 2 reduced.csv")

# %%
df.head()
# Out:
#       id  host_id  host_since  host_listings_count host_identity_verified  \
# 0  92644   498201  2011-04-10                  1.0                      t
# 1  93015   499704  2011-04-11                  1.0                      t
# 2  13913    54730  2009-11-16                  3.0                      t
# 3  15400    60302  2009-12-05                  1.0                      t
# 4  93734   497514  2011-04-10                  1.0                      t
#
#    calculated_host_listings_count                property_type  \
# 0                               1  Private room in rental unit
# 1                               1           Entire rental unit
# 2                               2  Private room in rental unit
# 3                               1           Entire rental unit
# 4                               1        Private room in condo
#
#          room_type instant_bookable  minimum_nights  ...  host_is_superhost  \
# ...

# %%
import pandas as pd

# Assuming your dataset is stored in a DataFrame called 'df'

# Step 1: Classify hosts as professional or non-professional
df['host_type'] = df.groupby('host_id')['neighbourhood_cleansed'].transform('nunique')
df['host_type'] = df['host_type'].apply(lambda x: 'professional' if x > 5 else 'non-professional')

# # Step 2: Calculate average price for professional and non-professional hosts
# avg_price_professional = df[df['host_type'] == 'professional']['price'].mean()
# avg_price_non_professional = df[df['host_type'] == 'non-professional']['price'].mean()

# # Step 3: Calculate the average price difference
# price_difference = avg_price_professional - avg_price_non_professional

# print("Average price for professional hosts:", avg_price_professional)
# print("Average price for non-professional hosts:", avg_price_non_professional)
# print("Price difference between professional and non-professional hosts:", price_difference)
# Out:
# 0        non-professional
# 1        non-professional
# 2        non-professional
# 3        non-professional
# 4        non-professional
#                ...
# 87941    non-professional
# 87942    non-professional
# 87943    non-professional
# 87944        professional
# 87945    non-professional
# Name: host_type, Length: 87946, dtype: object

# %%
ar = [1,2,3]
for i in ar:
    print(i)
# Out:
# 1
# 2
# 3
